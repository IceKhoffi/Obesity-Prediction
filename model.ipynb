# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
RANDOM_SEED = 27

# %% [markdown]
# ## Load Data

# %% [raw]
# a. Gender = Laki-laki atau Wanita
# b. Age = Usia seseorang dalam tahun
# c. Height = Tinggi dalam meter
# d. Weight = Berat dalam kilogram
# e. family_history_with_overweight = Apakah orang tersebut memiliki riwayat keluarga dengan kelebihan
# berat badan
# f. FAVC = Jika orang tersebut sering mengonsumsi makanan berkalori tinggi (ya/tidak)
# g. FCVC = Frekuensi konsumsi sayuran (skala dari 1 hingga 3)
# h. NCP = Jumlah makanan utama per hari
# i. CAEC = Frekuensi mengonsumsi makanan di antara waktu makan (Tidak pernah, Kadang-kadang,
# Sering, Selalu)
# j. SMOKE = Apakah orang tersebut merokok (ya/tidak)
# k. CH2O = Asupan air harian (skala dari 1 hingga 3)
# l. SCC = Jika orang tersebut memantau asupan kalori mereka (ya/tidak)
# m. FAF = Frekuensi aktivitas fisik (skala dari 0 hingga 3)
# n. TUE = Waktu yang dihabiskan untuk menggunakan teknologi (skala dari 0 hingga 3)
# o. CALC = Frekuensi konsumsi alkohol (Tidak pernah, Kadang-kadang, Sering, Selalu)
# p. MTRANS = Moda transportasi utama (Mobil, Sepeda, Sepeda Motor, Transportasi Umum, Jalan Kaki)
# q. NObeyesedad = Tingkat obesitas (Insufficient Weight, Normal Weight, Overweight Level I, Overweight Level II, Obesity Type I, Obesity Type II, Obesity Type III)

# %%
df = pd.read_csv("data/ObesityDataSet2.csv")
df.head()
# Out:
#    Gender Age  Height  Weight family_history_with_overweight FAVC  FCVC   NCP  \
# 0  Female  24    1.58   65.29                            yes   no  2.03  2.74
# 1    Male  23    1.65   66.00                             no   no  3.00  3.00
# 2  Female  21    1.69   51.26                            yes  yes  3.00  3.18
# 3  Female  22    1.69   65.00                            yes  yes  2.00  3.00
# 4  Female  23    1.61   82.64                            yes  yes  2.96  1.00
#
#          CAEC SMOKE  CH2O SCC   FAF    TUE       CALC                 MTRANS  \
# 0   Sometimes    no  2.00  no  1.28  1.019         no  Public_Transportation
# 1   Sometimes    no  2.00  no  3.00  0.000         no  Public_Transportation
# 2  Frequently    no  1.91  no  0.48  0.625         no  Public_Transportation
# 3   Sometimes    no  2.00  no  1.00  1.000  Sometimes  Public_Transportation
# 4   Sometimes    no  2.98  no  0.74  2.000  Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %% [markdown]
# ## Column Renaming
#
# Jadi karena susah diartikan untuk nama kolomnya jadi dalam hal ini renaming dilakukan agar mempermudah mengartikan tanpa menghilangkan arti dari kolom itu sendiri.

# %%
df.rename(columns = {
    'Gender' : 'gender',
    'Age' : 'age',
    'Height' : 'height_m',
    'Weight' : 'weight_kg',
    'family_history_with_overweight' : 'family_overweight_history',
    'FAVC' : 'high_cal_food_freq',
    'FCVC' : 'vegetable_consumtion_freq',
    'NCP' : 'main_meal_count',
    'CAEC' : 'snack_freq',
    'SMOKE' : 'is_smoker',
    'CH2O' : 'water_intake_level',
    'SCC' : 'is_cal_monitor',
    'FAF' : 'physical_activity_freq',
    'TUE' : 'tech_use_time',
    'CALC' : 'alcohol_consumption_freq',
    'MTRANS' : 'main_transport_mode',
    'NObeyesdad' : 'obesity_level'
}, inplace = True)

# %%
df.head()
# Out:
#    gender age  height_m  weight_kg family_overweight_history  \
# 0  Female  24      1.58      65.29                       yes
# 1    Male  23      1.65      66.00                        no
# 2  Female  21      1.69      51.26                       yes
# 3  Female  22      1.69      65.00                       yes
# 4  Female  23      1.61      82.64                       yes
#
#   high_cal_food_freq  vegetable_consumtion_freq  main_meal_count  snack_freq  \
# 0                 no                       2.03             2.74   Sometimes
# 1                 no                       3.00             3.00   Sometimes
# 2                yes                       3.00             3.18  Frequently
# 3                yes                       2.00             3.00   Sometimes
# 4                yes                       2.96             1.00   Sometimes
#
#   is_smoker  water_intake_level is_cal_monitor  physical_activity_freq  \
# ...

# %%
df.shape
# Out:
# (1056, 17)

# %% [markdown]
# ## Drop Duplicate
#
# Selanjutnya duplicate di drop "jika ada" untuk menghindari overfitting pada model

# %%
df[df.duplicated()].shape
# Out:
# (10, 17)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1046, 17)

# %% [markdown]
# ## Split Data
#
# Jadi sebelum masuk ke EDA (Exploratory Data Analysis), splitting dilakukan agar tidak terjadi data leak.

# %%
df['obesity_level'].value_counts()
# Out:
# obesity_level
# Obesity_Type_I         176
# Obesity_Type_III       162
# Obesity_Type_II        149
# Overweight_Level_II    145
# Normal_Weight          140
# Overweight_Level_I     139
# Insufficient_Weight    135
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['obesity_level'], axis=1)
y = df['obesity_level']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED, stratify=y)

train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

print(train.shape)
print(test.shape)
# Out:
# (836, 17)
# (210, 17)

# %%
train['obesity_level'].value_counts()
# Out:
# obesity_level
# Obesity_Type_I         141
# Obesity_Type_III       129
# Obesity_Type_II        119
# Overweight_Level_II    116
# Normal_Weight          112
# Overweight_Level_I     111
# Insufficient_Weight    108
# Name: count, dtype: int64

# %%
test['obesity_level'].value_counts()
# Out:
# obesity_level
# Obesity_Type_I         35
# Obesity_Type_III       33
# Obesity_Type_II        30
# Overweight_Level_II    29
# Overweight_Level_I     28
# Normal_Weight          28
# Insufficient_Weight    27
# Name: count, dtype: int64

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
train.head()
# Out:
#      gender       age  height_m  weight_kg family_overweight_history  \
# 870  Female        26      1.62     104.85                       yes
# 309  Female  19 years      1.50      45.00                        no
# 834  Female        23      1.66      60.00                       yes
# 252  Female        16      1.66      58.00                        no
# 350    Male        17      1.81      58.83                       yes
#
#     high_cal_food_freq  vegetable_consumtion_freq  main_meal_count snack_freq  \
# 870                yes                       3.00             3.00  Sometimes
# 309                yes                       2.00             3.00  Sometimes
# 834                yes                       2.00             1.00  Sometimes
# 252                 no                       2.00             1.00  Sometimes
# 350                yes                       2.48             3.76  Sometimes
#
#     is_smoker  water_intake_level is_cal_monitor  physical_activity_freq  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 836 entries, 870 to 345
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   gender                     836 non-null    object
#  1   age                        836 non-null    object
#  2   height_m                   836 non-null    float64
#  3   weight_kg                  836 non-null    float64
#  4   family_overweight_history  836 non-null    object
#  5   high_cal_food_freq         836 non-null    object
#  6   vegetable_consumtion_freq  808 non-null    float64
#  7   main_meal_count            836 non-null    float64
#  8   snack_freq                 836 non-null    object
#  9   is_smoker                  836 non-null    object
#  10  water_intake_level         836 non-null    float64
#  11  is_cal_monitor             836 non-null    object
#  12  physical_activity_freq     836 non-null    float64
# ...

# %%
def num_cat(df):
    """
    num_cat : berfungsi untuk memisahkan antara categorical dan numerical variabel.

    df : Dataframe

    return : list numerical serta categorical variable
    """
    num = []
    cat = []

    for _ in df.columns:
        if df[_].dtype == 'object':
            cat.append(_)
        else:
            num.append(_)

    return num,cat
    
num, cat = num_cat(train)

# %% [markdown]
# ## Categorical Data

# %%
cat
# Out:
# ['gender',
#  'age',
#  'family_overweight_history',
#  'high_cal_food_freq',
#  'snack_freq',
#  'is_smoker',
#  'is_cal_monitor',
#  'alcohol_consumption_freq',
#  'main_transport_mode',
#  'obesity_level']

# %% [raw]
# gender : laki-lagi atau wanita

# %%
train['gender'].value_counts()
# Out:
# gender
# Female    426
# Male      410
# Name: count, dtype: int64

# %% [raw]
# age : usia seseorang dalam tahun

# %%
train['age'].unique()
# Out:
# array(['26', '19 years', '23', '16', '17', '18', '27', '40', '33', '24',
#        '29', '30', '19', '31', '22', '25', '21', '39', '41', '22 years',
#        '34', '45', '20', '14', '35', '38', '44', '32', '37', '28',
#        '17 years', '36', '23 years', '51', '48', '55', '26 years', '43',
#        '36 years', '25 years', '46', '21 years', '42'], dtype=object)

# %% [raw]
# Jadi setelah melihat unique dari age yang sebelumnya diketahui bahwa tipe data kolom age itu salah yang seharusnya, integer namun pas dicheck merupakan object / string artinya ada terjadi salah input pada data. Dengan begitu perubahan dilakukan menggunakan regex agar lebih mempermudah

# %%
train['age'] = train['age'].str.replace(r'\D', '', regex=True)
train['age'] = pd.to_numeric(train['age'])
train['age'].unique()
# Out:
# array([26, 19, 23, 16, 17, 18, 27, 40, 33, 24, 29, 30, 31, 22, 25, 21, 39,
#        41, 34, 45, 20, 14, 35, 38, 44, 32, 37, 28, 36, 51, 48, 55, 43, 46,
#        42])

# %%
test['age'] = test['age'].str.replace(r'\D', '', regex=True)
test['age'] = pd.to_numeric(test['age'])

# %% [raw]
# family_overweight_history : Apakah orang tersebut memiliki riwayat keluarga dengan kelebihan berat badan

# %% [raw]
# high_cal_food_freq : Jika orang tersebut sering mengonsumsi makanan berkalori tinggi (ya/tidak)

# %%
train['family_overweight_history'].value_counts()
# Out:
# family_overweight_history
# yes    690
# no     146
# Name: count, dtype: int64

# %%
train['high_cal_food_freq'].value_counts()
# Out:
# high_cal_food_freq
# yes    742
# no      94
# Name: count, dtype: int64

# %% [raw]
# snack_freq : Frekuensi mengonsumsi makanan di antara waktu makan (Tidak pernah, Kadang-kadang, Sering, Selalu)

# %%
train['snack_freq'].value_counts()
# Out:
# snack_freq
# Sometimes     693
# Frequently    101
# Always         22
# no             20
# Name: count, dtype: int64

# %% [raw]
# is_smoker : Apakah orang tersebut merokok (ya/tidak)

# %%
train['is_smoker'].value_counts()
# Out:
# is_smoker
# no     816
# yes     20
# Name: count, dtype: int64

# %% [raw]
# is_cal_monitor :  Jika orang tersebut memantau asupan kalori mereka (ya/tidak)

# %%
train['is_cal_monitor'].value_counts()
# Out:
# is_cal_monitor
# no     794
# yes     42
# Name: count, dtype: int64

# %% [raw]
# alcohol_consumption_freq : Frekuensi konsumsi alkohol (Tidak pernah, Kadang-kadang, Sering, Selalu)

# %%
train['alcohol_consumption_freq'].value_counts()
# Out:
# alcohol_consumption_freq
# Sometimes     552
# no            257
# Frequently     26
# Always          1
# Name: count, dtype: int64

# %% [raw]
# main_transport_mode :  Moda transportasi utama (Mobil, Sepeda, Sepeda Motor, Transportasi Umum, Jalan Kaki)

# %%
train['main_transport_mode'].value_counts()
# Out:
# main_transport_mode
# Public_Transportation    609
# Automobile               174
# Walking                   22
# Motorbike                  8
# Bike                       3
# Name: count, dtype: int64

# %% [markdown]
# ## Numerical Data

# %%
num
# Out:
# ['height_m',
#  'weight_kg',
#  'vegetable_consumtion_freq',
#  'main_meal_count',
#  'water_intake_level',
#  'physical_activity_freq',
#  'tech_use_time']

# %% [raw]
# height_m : Tinggi dalam meter

# %%
train['height_m'].describe()
# Out:
# count    836.000000
# mean       1.699079
# std        0.093291
# min        1.450000
# 25%        1.630000
# 50%        1.700000
# 75%        1.760000
# max        1.950000
# Name: height_m, dtype: float64

# %%
train['height_m'].head()
# Out:
# 870    1.62
# 309    1.50
# 834    1.66
# 252    1.66
# 350    1.81
# Name: height_m, dtype: float64

# %% [raw]
# weight_kg : Berat dalam kilogram

# %%
train['weight_kg'].describe()
# Out:
# count    836.000000
# mean      86.482309
# std       26.227455
# min       39.000000
# 25%       65.977500
# 50%       82.470000
# 75%      107.967500
# max      173.000000
# Name: weight_kg, dtype: float64

# %%
train['weight_kg'].head()
# Out:
# 870    104.85
# 309     45.00
# 834     60.00
# 252     58.00
# 350     58.83
# Name: weight_kg, dtype: float64

# %% [raw]
# vegetable_consumtion_freq : Frekuensi konsumsi sayuran (skala dari 1 hingga 3)

# %%
train['vegetable_consumtion_freq'].describe()
# Out:
# count    808.000000
# mean       2.413626
# std        0.545805
# min        1.000000
# 25%        2.000000
# 50%        2.380000
# 75%        3.000000
# max        3.000000
# Name: vegetable_consumtion_freq, dtype: float64

# %%
train['vegetable_consumtion_freq'].head()
# Out:
# 870    3.00
# 309    2.00
# 834    2.00
# 252    2.00
# 350    2.48
# Name: vegetable_consumtion_freq, dtype: float64

# %% [raw]
# Karena berdasarkan deskripsi vegetable_consumtion_freq | frekuensi konsumsi sayuran berdasarkan skala dari 1 hingga 3 jadinya data ini tidak mungkin float pastinya integer. Maka dalam hal ini ada baiknya nilai pada vegetable_consumtion_freq kita bulatkan dan diubah ke integer

# %% [raw]
# main_meal_count : Jumlah makanan utama per hari

# %%
train['main_meal_count'].describe()
# Out:
# count    836.000000
# mean       2.642978
# std        0.806036
# min        1.000000
# 25%        2.415000
# 50%        3.000000
# 75%        3.000000
# max        4.000000
# Name: main_meal_count, dtype: float64

# %%
train['main_meal_count'].head()
# Out:
# 870    3.00
# 309    3.00
# 834    1.00
# 252    1.00
# 350    3.76
# Name: main_meal_count, dtype: float64

# %% [raw]
# Sama seperti vegetable_consumtion_freq | kita tau bahwa main_meal_count karena berupa "count" pastinya itu hanya dapat menjadi bilangan bulat positif.

# %% [raw]
# water_intake_level : Asupan air harian (skala dari 1 hingga 3)

# %%
train['water_intake_level'].describe()
# Out:
# count    836.000000
# mean       1.991555
# std        0.608820
# min        1.000000
# 25%        1.530000
# 50%        2.000000
# 75%        2.432500
# max        3.000000
# Name: water_intake_level, dtype: float64

# %%
train['water_intake_level'].head()
# Out:
# 870    2.65
# 309    1.00
# 834    1.00
# 252    1.00
# 350    2.00
# Name: water_intake_level, dtype: float64

# %% [raw]
# Sama seperti sebelumnya karena skala artinya hanya bisa berupa "bilangan bulat positif"

# %% [raw]
# physical_activity_freq : Frekuensi aktivitas fisik (skala dari 0 hingga 3)

# %%
train['physical_activity_freq'].describe()
# Out:
# count    836.000000
# mean       0.985658
# std        0.848399
# min        0.000000
# 25%        0.100000
# 50%        1.000000
# 75%        1.600000
# max        3.000000
# Name: physical_activity_freq, dtype: float64

# %%
train['physical_activity_freq'].head()
# Out:
# 870    0.0
# 309    0.0
# 834    1.0
# 252    0.0
# 350    2.0
# Name: physical_activity_freq, dtype: float64

# %% [raw]
# Walaupun melihat data 'physical_activity_freq' bagian head tidak ada kesalahan namun ketika melakukan statistic describe diketahui bahwa quartile 25% juga quartile 75% masih terdapat nilai yang salah karena untuk 'physical_activity_freq' berupa skala dari 0 hingga 3

# %% [raw]
# tech_use_time : Waktu yang dihabiskan untuk menggunakan teknologi (skala dari 0 hingga 3)

# %%
train['tech_use_time'].describe()
# Out:
# count    836.000000
# mean       0.647664
# std        0.620272
# min        0.000000
# 25%        0.000000
# 50%        0.585500
# 75%        1.000000
# max        2.000000
# Name: tech_use_time, dtype: float64

# %%
train['tech_use_time'].head()
# Out:
# 870    0.554
# 309    0.000
# 834    1.000
# 252    1.000
# 350    0.930
# Name: tech_use_time, dtype: float64

# %% [raw]
# Sama seperti kolom" sebelumnya yang mirip dimana pembulatan akan dilakukan dan tipe data diubah ke "int" dikarenakan skala 0 hingga 3 atau "bilangan bulat positif"

# %% [markdown]
# ## Missing Values

# %%
def missing_values(df):
    """
    df : Dataframe
    
    return : Dataframe with missing values sum and percentage
    
    """
    missing = df.isnull().sum()
    missing_percentage = df.isnull().sum() / df.shape[0] * 100
    missing = pd.concat([missing, missing_percentage], axis=1)
    missing.columns = ['Missing Values', 'Missing Values Percentage']
    return missing[missing['Missing Values'] > 0]

# %%
missing_values(train)
# Out:
#                            Missing Values  Missing Values Percentage
# vegetable_consumtion_freq              28                   3.349282
# main_transport_mode                    20                   2.392344

# %%
missing_values(test)
# Out:
#                            Missing Values  Missing Values Percentage
# vegetable_consumtion_freq               9                   4.285714
# main_transport_mode                     6                   2.857143

# %% [markdown]
# # Pipeline Modelling for Preprocessing

# %%
train_prep = train.copy()
test_prep = test.copy()

# %%
train_prep.head()
# Out:
#      gender  age  height_m  weight_kg family_overweight_history  \
# 870  Female   26      1.62     104.85                       yes
# 309  Female   19      1.50      45.00                        no
# 834  Female   23      1.66      60.00                       yes
# 252  Female   16      1.66      58.00                        no
# 350    Male   17      1.81      58.83                       yes
#
#     high_cal_food_freq  vegetable_consumtion_freq  main_meal_count snack_freq  \
# 870                yes                       3.00             3.00  Sometimes
# 309                yes                       2.00             3.00  Sometimes
# 834                yes                       2.00             1.00  Sometimes
# 252                 no                       2.00             1.00  Sometimes
# 350                yes                       2.48             3.76  Sometimes
#
#     is_smoker  water_intake_level is_cal_monitor  physical_activity_freq  \
# ...

# %% [markdown]
# ## Preprocessing pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, FunctionTransformer

# %% [markdown]
# ### Numerical features

# %%
#Fixing Values
round_ft = ['vegetable_consumtion_freq', 'main_meal_count', 'water_intake_level',
       'physical_activity_freq', 'tech_use_time']

# %% [raw]
# List features diatas itu merupakan kolom numerical dimana berbentuk skala
#
# example :
# tech_use_time -> Waktu yang dihabiskan untuk menggunakan teknologi (skala dari 0 hingga 3)

# %%
def rounding(x):
    return np.round(x).astype(int)

round_ft_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')), #karena skala 
    ('rounder', FunctionTransformer(rounding))
])

# %%
#Ordinal Categorical Pipeline
ordinal_ft = ['snack_freq', 'alcohol_consumption_freq']
order = [['no', 'Sometimes', 'Frequently', 'Always'],
         ['no', 'Sometimes', 'Frequently', 'Always']]

# %%
ordinal_ft_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder(categories=order))
])

# %%
#Binary Categorical Pipeline
binary_ft = ['gender', 'family_overweight_history',
             'high_cal_food_freq', 'is_smoker', 'is_cal_monitor']

def binary_encode(x):
    x = pd.DataFrame(x, columns=binary_ft)
    return x.replace({'Male': 1, 'Female': 0, 'yes': 1, 'no': 0}).values

# %%
binary_ft_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', FunctionTransformer(binary_encode))
])

# %%
#Categorical Variabel Pipeline
cat_ft = ['main_transport_mode']

# %%
cat_ft_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

# %%
#Numerical Variable Pipeline
num_ft = ['age','height_m', 'weight_kg']

num_ft_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean'))
])

# %%
from sklearn.compose import ColumnTransformer

# Combine all pipelines
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_ft_pipeline, num_ft),
        ('binary', binary_ft_pipeline, binary_ft),
        ('round', round_ft_pipeline, round_ft),
        ('ordinal', ordinal_ft_pipeline, ordinal_ft),
        ('ohe', cat_ft_pipeline, cat_ft)
    ], remainder='drop'
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer', SimpleImputer())]),
#                                  ['age', 'height_m', 'weight_kg']),
#                                 ('binary',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   FunctionTransformer(func=<function binary_encode at 0x7f0e6ef73240>))]),
#                                  ['gender', 'family_overweight_history',
#                                   'high_cal_food_freq', 'is_smoker',
#                                   'is_...
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
# ...

# %%
train_prep.head()
# Out:
#      gender  age  height_m  weight_kg family_overweight_history  \
# 870  Female   26      1.62     104.85                       yes
# 309  Female   19      1.50      45.00                        no
# 834  Female   23      1.66      60.00                       yes
# 252  Female   16      1.66      58.00                        no
# 350    Male   17      1.81      58.83                       yes
#
#     high_cal_food_freq  vegetable_consumtion_freq  main_meal_count snack_freq  \
# 870                yes                       3.00             3.00  Sometimes
# 309                yes                       2.00             3.00  Sometimes
# 834                yes                       2.00             1.00  Sometimes
# 252                 no                       2.00             1.00  Sometimes
# 350                yes                       2.48             3.76  Sometimes
#
#     is_smoker  water_intake_level is_cal_monitor  physical_activity_freq  \
# ...

# %%
X_train_prep = preprocessor.fit_transform(train_prep.drop('obesity_level', axis=1))

# %%
X_train_prep[0]
# Out:
# array([ 26.  ,   1.62, 104.85,   0.  ,   1.  ,   1.  ,   0.  ,   0.  ,
#          3.  ,   3.  ,   3.  ,   0.  ,   1.  ,   1.  ,   1.  ,   0.  ,
#          0.  ,   0.  ,   1.  ,   0.  ])

# %%
print(num_ft)
print(binary_ft)
print(round_ft)
print(ordinal_ft)
print(cat_ft)
# Out:
# ['age', 'height_m', 'weight_kg']
# ['gender', 'family_overweight_history', 'high_cal_food_freq', 'is_smoker', 'is_cal_monitor']
# ['vegetable_consumtion_freq', 'main_meal_count', 'water_intake_level', 'physical_activity_freq', 'tech_use_time']
# ['snack_freq', 'alcohol_consumption_freq']
# ['main_transport_mode']

# %%
train_prep.head(1)
# Out:
#      gender  age  height_m  weight_kg family_overweight_history  \
# 870  Female   26      1.62     104.85                       yes
#
#     high_cal_food_freq  vegetable_consumtion_freq  main_meal_count snack_freq  \
# 870                yes                        3.0              3.0  Sometimes
#
#     is_smoker  water_intake_level is_cal_monitor  physical_activity_freq  \
# 870        no                2.65             no                     0.0
#
#      tech_use_time alcohol_consumption_freq    main_transport_mode  \
# 870          0.554                Sometimes  Public_Transportation
#
#         obesity_level
# 870  Obesity_Type_III

# %% [markdown]
# ### Target Encoding

# %%
from sklearn.preprocessing import LabelEncoder
target_le = LabelEncoder()
y_train_prep = target_le.fit_transform(train_prep['obesity_level'])
y_test_prep = target_le.fit_transform(test_prep['obesity_level'])

# %%
target_le.classes_
# Out:
# array(['Insufficient_Weight', 'Normal_Weight', 'Obesity_Type_I',
#        'Obesity_Type_II', 'Obesity_Type_III', 'Overweight_Level_I',
#        'Overweight_Level_II'], dtype=object)

# %%
X_train_prep = preprocessor.fit_transform(train_prep.drop('obesity_level', axis=1))
X_test_prep = preprocessor.transform(test_prep.drop('obesity_level', axis=1))

# %% [markdown]
# # Training menggunakan dua Model
#
# RandomForestClassifier dan XGBClassifier

# %% [raw]
# Dalam kasus ini model yang dipilih ada tree based model dimana karena tidak dilakukan scaling pada data, jadi penggunaan model yang tidak terlalu berpengaruh pada outliers akan sangat membantu juga menggunakan tree based model juga membantu dari segi pemahaman model.

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
rf = RandomForestClassifier(random_state=RANDOM_SEED)
xgb = XGBClassifier(random_state=RANDOM_SEED)

# %% [markdown]
# ## RandomForestClassifier

# %%
rf.fit(X_train_prep, y_train_prep)
# Out:
# RandomForestClassifier(random_state=27)

# %%
y_pred = rf.predict(X_test_prep)

# %%
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_test_prep, y_pred, target_names=target_le.classes_))
# Out:
# Classification Report
#
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       1.00      0.96      0.98        27
#       Normal_Weight       0.75      0.86      0.80        28
#      Obesity_Type_I       1.00      0.97      0.99        35
#     Obesity_Type_II       1.00      1.00      1.00        30
#    Obesity_Type_III       1.00      1.00      1.00        33
#  Overweight_Level_I       0.87      0.71      0.78        28
# Overweight_Level_II       0.88      0.97      0.92        29
#
#            accuracy                           0.93       210
#           macro avg       0.93      0.92      0.92       210
#        weighted avg       0.93      0.93      0.93       210

# %% [markdown]
# ## XGBoostClassifier

# %%
xgb.fit(X_train_prep, y_train_prep)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(X_test_prep)

# %%
print('\nClassification Report\n')
print(classification_report(y_test_prep, y_pred, target_names=target_le.classes_))
# Out:
# Classification Report
#
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       1.00      1.00      1.00        27
#       Normal_Weight       0.96      0.82      0.88        28
#      Obesity_Type_I       1.00      1.00      1.00        35
#     Obesity_Type_II       1.00      1.00      1.00        30
#    Obesity_Type_III       1.00      1.00      1.00        33
#  Overweight_Level_I       0.83      0.89      0.86        28
# Overweight_Level_II       0.90      0.97      0.93        29
#
#            accuracy                           0.96       210
#           macro avg       0.96      0.95      0.95       210
#        weighted avg       0.96      0.96      0.96       210

# %% [markdown]
# # Menggabungkan Best Model dengan Pipeline

# %%
obes_pred = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', XGBClassifier(random_state=RANDOM_SEED))
])

# %%
obes_pred
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['age', 'height_m',
#                                                    'weight_kg']),
#                                                  ('binary',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    FunctionTransformer(func=<function binary_encode at 0x7f0e6ef73240>))]),
#                                                   ['gender',
# ...

# %%
obes_pred.fit(train_prep.drop('obesity_level', axis=1), y_train_prep)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['age', 'height_m',
#                                                    'weight_kg']),
#                                                  ('binary',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    FunctionTransformer(func=<function binary_encode at 0x7f0e6ef73240>))]),
#                                                   ['gender',
# ...

# %%
obes_y_pre = obes_pred.predict(test_prep.drop('obesity_level', axis=1))

# %%
print('\nClassification Report\n')
print(classification_report(y_test_prep, obes_y_pre, target_names=target_le.classes_))
# Out:
# Classification Report
#
#                      precision    recall  f1-score   support
#
# Insufficient_Weight       1.00      1.00      1.00        27
#       Normal_Weight       0.96      0.82      0.88        28
#      Obesity_Type_I       1.00      1.00      1.00        35
#     Obesity_Type_II       1.00      1.00      1.00        30
#    Obesity_Type_III       1.00      1.00      1.00        33
#  Overweight_Level_I       0.83      0.89      0.86        28
# Overweight_Level_II       0.90      0.97      0.93        29
#
#            accuracy                           0.96       210
#           macro avg       0.96      0.95      0.95       210
#        weighted avg       0.96      0.96      0.96       210

# %%
import pickle as pkl
filename = 'sun_pipeline.pkl'
pkl.dump(obes_pred, open(filename, 'wb'))

# %%
filename = 'model/target_le.pkl'
pkl.dump(target_le, open(filename, 'wb'))
